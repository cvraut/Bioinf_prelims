# %% [markdown]
# # Faculty Search

# %% [markdown]
# So I need to assemble a list of 4 faculty and they need to fulfill this loose set of criteria:
# - 3/4 must be from Bioinformatics (DCM&B or CCM&B) at associate-level or higher
# - \>=1 must be computational
# - \>=1 must be biomedical
# - \>=1 must be DCMB faculty
# - diversity (female & non-white)
#
# Original text: "At the same time as submitting the abstract, the student must also propose the names of four faculty members for their preliminary examination committee. Three of the four must be Bioinformatics-affiliated faculty. To clarify, this must be DCM&B or CCMB faculty who are either instructor tenure-track or if research-track, at the Associate-level or higher. At least one member must be computational and at least one biomedical, and at least one should be a DCMB faculty member."

# %% [markdown]
# So this notebook is supposed to scrape the DCMB catalogue to identify a group of professors who can fit this criteria

# %%
# imports
import requests
from bs4 import BeautifulSoup
import cloudscraper
from collections import defaultdict
from random import choice
from time import sleep
from pickle import dump, load
import re

# %%
faculty_list_url = "https://medicine.umich.edu/dept/dcmb/faculty/faculty/all?page={}" #0-4
scraper = cloudscraper.create_scraper()  # returns a CloudScraper instance

user_agents = [
  "Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0",
  "Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0",
  "Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0",
  'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,'
  ]
ua = choice(user_agents)
print(ua)
page = scraper.get(faculty_list_url.format(0),headers={'User-Agent': ua})
# Out:
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0

# %%
faculty_to_info = defaultdict(dict)
for i in range(5):
    page = None
    while not page:
        try:
            ua = choice(user_agents)
            print(ua)
            page = scraper.get(faculty_list_url.format(i),headers={'User-Agent': ua})
        except Exception as e:
            naptime = choice(range(0,5,0.1))
            print("encountered DDOS protection on {}. Sleeping for {} seconds & retrying 😴 ...".format(faculty_list_url.format(0),naptime))
            sleep(naptime)
    soup = BeautifulSoup(page.text, 'html.parser')
    for art in soup.find_all("article"):
        for head in art.find_all("h2"):
            for a in head.find_all("a"):
                print(a["href"],a.text)
                faculty_to_info[a.text]["link"] = "https://medicine.umich.edu{}".format(a["href"])
# Out:
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# /dept/dcmb/brian-d-athey-phd Brian D. Athey, Ph.D.
# /dept/dcmb/philip-c-andrews-phd Philip C Andrews, Ph.D.
# /dept/dcmb/sara-aton-phd Sara Aton, Ph.D.
# /dept/dcmb/kin-fai-au-phd Kin Fai Au, Ph.D.
# /dept/dcmb/james-r-baker-jr-md James R.  Baker, Jr., M.D.
# /dept/dcmb/veera-baladandayuthapani-phd Veera Baladandayuthapani, Ph.D.
# /dept/dcmb/scott-barolo-phd Scott Barolo, Ph.D.
# /dept/dcmb/anthony-bloch Anthony Bloch
# /dept/dcmb/michael-boehnke-phd Michael Boehnke, Ph.D.
# /dept/dcmb/victoria-booth-phd Victoria Booth, Ph.D.
# /dept/dcmb/alan-boyle-phd Alan Boyle, Ph.D.
# /dept/dcmb/charles-l-brooks-iii-phd Charles L. Brooks, III, Ph.D.
# /dept/dcmb/charles-f-burant-md-phd Charles F.  Burant, M.D., Ph.D.
# /dept/dcmb/margit-burmeister-phd Margit Burmeister, Ph.D.
# /dept/dcmb/daniel-burns-jr-phd Daniel Burns, Jr, Ph.D.
# /dept/dcmb/sally-camper-phd Sally Camper, Ph.D.
# /dept/dcmb/sriram-chandrasekaran-phd Sriram Chandrasekaran, Ph.D.
# /dept/dcmb/andrew-chang-md Andrew  Chang, M.D.
# /dept/dcmb/vivian-cheung-md Vivian  Cheung, M.D.
# /dept/dcmb/arul-m-chinnaiyan-md-phd Arul M.  Chinnaiyan, M.D., Ph.D.
# /dept/dcmb/marcin-cieslik-phd Marcin  Cieslik, Ph.D.
# /dept/dcmb/eleanor-j-josie-clowney-phd Eleanor J. "Josie" Clowney , Ph.D.
# /dept/dcmb/justin-colacino-phd Justin  Colacino, Ph.D.
# /dept/dcmb/felix-de-la-iglesia-md Felix  De La Iglesia , M.D.
# /dept/dcmb/greg-dick-phd Greg Dick, Ph.D.
# /dept/dcmb/ivo-dinov-phd Ivo Dinov, Ph.D.
# /dept/dcmb/nicholas-douville-md-phd Nicholas  Douville, MD, PhD
# /dept/dcmb/melissa-duhaime-phd Melissa  Duhaime, Ph.D.
# /dept/dcmb/charles-evans-phd Charles Evans, Ph.D.
# /dept/dcmb/eva-feldman-md-phd Eva Feldman, M.D., Ph.D.
# /dept/dcmb/daniel-forger-phd Daniel  Forger, Ph.D.
# /dept/dcmb/aaron-frank-phd Aaron Frank, Ph.D.
# /dept/dcmb/peter-freddolino-phd Peter Freddolino, Ph.D.
# /dept/dcmb/johann-gagnon-bartsch-phd Johann Gagnon-Bartsch, Ph.D.
# /dept/dcmb/craig-galban-phd Craig Galban, Ph.D.
# /dept/dcmb/santhi-ganesh-md Santhi Ganesh, M.D.
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# /dept/dcmb/thomas-w-gardner-md-ms Thomas W. Gardner, M.D., M.S.
# /dept/dcmb/krishna-garikipati-phd Krishna  Garikipati, Ph.D.
# /dept/dcmb/lana-garmire-phd Lana Garmire, Ph.D.
# /dept/dcmb/sharon-c-glotzer-phd Sharon C. Glotzer, Ph.D.
# /dept/dcmb/richard-gonzalez-phd Richard  Gonzalez, Ph.D.
# /dept/dcmb/yuanfang-guan-phd Yuanfang Guan, Ph.D.
# /dept/dcmb/stephen-t-guest-phd Stephen T.  Guest, Ph.D.
# /dept/dcmb/deborah-gumucio-phd Deborah  Gumucio, Ph.D.
# /dept/dcmb/david-hanauer-md-ms David A.  Hanauer, M.D., M.S.
# /dept/dcmb/yongqun-oliver-he-phd Yongqun "Oliver" He, Ph.D.
# /dept/dcmb/idse-heemskerk-phd Idse Heemskerk, Ph.D.
# /dept/dcmb/alfred-hero-phd Alfred  Hero, Ph.D.
# /dept/dcmb/todd-hollon-md Todd Hollon, M.D.
# /dept/dcmb/trachette-l-jackson-phd Trachette L. Jackson, Ph.D.
# /dept/dcmb/hosagrahar-v-jagadish-phd Hosagrahar V. Jagadish, Ph.D.
# /dept/dcmb/hui-jiang-phd Hui  Jiang, Ph.D.
# /dept/dcmb/olivier-jolliet-phd Olivier  Jolliet, Ph.D.
# /dept/dcmb/wenjun-ju-phd Wenjun  Ju, Ph.D.
# /dept/dcmb/niko-kaciroti-phd Niko Kaciroti, Ph.D.
# /dept/dcmb/hyun-min-kang-phd Hyun Min Kang, Ph.D.
# /dept/dcmb/sharon-lr-kardia-phd Sharon L.R. Kardia, Ph.D.
# /dept/dcmb/alla-karnovsky-phd Alla Karnovsky, Ph.D.
# /dept/dcmb/evan-t-keller-dvm-phd Evan T. Keller, D.V.M., Ph.D.
# /dept/dcmb/jeff-kidd-phd Jeff Kidd, Ph.D.
# /dept/dcmb/minji-kim-phd Minji  Kim, Ph.D.
# /dept/dcmb/aaron-alan-king-phd Aaron Alan King, Ph.D.
# /dept/dcmb/denise-e-kirschner-phd Denise E. Kirschner, Ph.D.
# /dept/dcmb/jacob-kitzman-phd Jacob Kitzman, Ph.D.
# /dept/dcmb/alexey-kondrashov-phd Alexey Kondrashov, Ph.D.
# /dept/dcmb/frederick-korley-md-phd Frederick  Korley, M.D., Ph.D.
# /dept/dcmb/danai-koutra-phd Danai  Koutra, Ph.D.
# /dept/dcmb/robert-krasny-phd Robert Krasny, Ph.D.
# /dept/dcmb/matthias-kretzler-md Matthias Kretzler, M.D.
# /dept/dcmb/anuj-kumar-phd Anuj Kumar, Ph.D.
# /dept/dcmb/shayanki-lahiri-phd Shayanki Lahiri, Ph.D.
# /dept/dcmb/ronald-g-larson-phd Ronald G. Larson, Ph.D.
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# /dept/dcmb/christian-lastoskie-phd Christian  Lastoskie, Ph.D.
# /dept/dcmb/joonsang-lee-phd Joonsang Lee, Ph.D.
# /dept/dcmb/jun-hee-lee Jun Hee Lee
# /dept/dcmb/jun-li-phd Jun Li, Ph.D.
# /dept/dcmb/xiaoxia-nina-lin-phd Xiaoxia "Nina" Lin, Ph.D.
# /dept/dcmb/jennifer-linderman-phd Jennifer  Linderman, Ph.D.
# /dept/dcmb/jie-liu-phd Jie Liu, Ph.D.
# /dept/dcmb/mats-ljungman-phd Mats Ljungman, Ph.D.
# /dept/dcmb/david-k-lubensky-phd David K. Lubensky, Ph.D.
# /dept/dcmb/david-m-lubman-phd David M. Lubman, Ph.D.
# /dept/dcmb/michael-mathis-md Michael  Mathis, M.D.
# /dept/dcmb/melvin-mcinnis-md Melvin McInnis, M.D.
# /dept/dcmb/fan-meng-phd Fan Meng, Ph.D.
# /dept/dcmb/rajasree-menon-phd Rajasree  Menon, Ph.D.
# /dept/dcmb/sofia-d-merajver-md-phd Sofia D.  Merajver, M.D., Ph.D.
# /dept/dcmb/richard-miller-phd Richard A. Miller, Ph.D.
# /dept/dcmb/ryan-e-mills-phd Ryan E. Mills, Ph.D.
# /dept/dcmb/cristina-mitrea-phd Cristina  Mitrea, Ph.D.
# /dept/dcmb/john-v-moran-phd John V. Moran, Ph.D.
# /dept/dcmb/lindsey-muir-phd Lindsey  Muir, Ph.D.
# /dept/dcmb/kayvan-najarian-phd Kayvan Najarian, Ph.D.
# /dept/dcmb/nambi-nallasamy-md Nambi  Nallasamy, M.D.
# /dept/dcmb/alexey-nesvizhskii-phd Alexey Nesvizhskii, Ph.D.
# /dept/dcmb/douglas-noll-phd Douglas  Noll, Ph.D.
# /dept/dcmb/matthew-omeara-phd Matthew  O'Meara, Ph.D.
# /dept/dcmb/gilbert-s-omenn-md-phd Gilbert S. Omenn, M.D., Ph.D.
# /dept/dcmb/stephen-cj-parker-phd Stephen CJ Parker, Ph.D.
# /dept/dcmb/subramanium-pennathur-md Subramanium  Pennathur, M.D.
# /dept/dcmb/tingting-qin-phd Tingting Qin, Ph.D.
# /dept/dcmb/indika-rajapakse-phd Indika Rajapakse, Ph.D.
# /dept/dcmb/arvind-rao-phd Arvind  Rao, Ph.D.
# /dept/dcmb/rajesh-rao-md Rajesh  Rao , MD
# /dept/dcmb/jeffrey-regier-phd Jeffrey Regier, Ph.D.
# /dept/dcmb/rudy-j-richardson-scd-dabt Rudy J. Richardson, Sc.D., D.A.B.T.
# /dept/dcmb/thomas-ried-phd Thomas Ried, Ph.D.
# /dept/dcmb/gustavo-rosania-phd Gustavo Rosania, Ph.D.
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# /dept/dcmb/brandon-ruotolo-phd Brandon  Ruotolo, Ph.D.
# /dept/dcmb/maureen-sartor-phd Maureen Sartor, Ph.D.
# /dept/dcmb/robert-savit-phd Robert Savit, Ph.D.
# /dept/dcmb/patrick-schloss-phd Patrick  Schloss, Ph.D.
# /dept/dcmb/jessica-schwartz-phd Jessica  Schwartz, Ph.D.
# /dept/dcmb/clayton-scott-phd Clayton  Scott, Ph.D.
# /dept/dcmb/laura-scott-phd Laura Scott, Ph.D.
# /dept/dcmb/srijan-sen-md-phd Srijan  Sen, M.D., Ph.D.
# /dept/dcmb/david-sept-phd David Sept, Ph.D.
# /dept/dcmb/kerby-shedden-phd Kerby  Shedden, Ph.D.
# /dept/dcmb/david-sherman-phd David Sherman, Ph.D.
# /dept/dcmb/xu-shi-phd Xu Shi, Ph.D.
# /dept/dcmb/carl-simon-phd Carl Simon, Ph.D.
# /dept/dcmb/karandeep-singh-md-mmsc Karandeep  Singh, M.D., MMSc
# /dept/dcmb/michael-sjoding-md Michael  Sjoding, M.D.
# /dept/dcmb/stephen-smith-phd Stephen A. Smith, Ph.D.
# /dept/dcmb/evan-snitkin-phd Evan Snitkin, Ph.D.
# /dept/dcmb/elizabeth-k-speliotes-md-phd-mph Elizabeth K Speliotes, M.D., Ph.D., M.P.H.
# /dept/dcmb/ashok-srinivasan-md Ashok Srinivasan, MD
# /dept/dcmb/chandra-sripada-md-phd Chandra  Sripada, M.D., Ph.D.
# /dept/dcmb/ryan-stidham-md-msc Ryan  Stidham, M.D., M.Sc.
# /dept/dcmb/kathleen-stringer-pharmd Kathleen  Stringer, Pharm.D.
# /dept/dcmb/jeremy-taylor-phd Jeremy Taylor, Ph.D.
# /dept/dcmb/muneesh-tewari-phd Muneesh  Tewari, Ph.D.
# /dept/dcmb/lam-alex-tsoi-phd Lam "Alex" Tsoi, Ph.D.
# /dept/dcmb/michael-uhler-phd Michael  Uhler, Ph.D.
# /dept/dcmb/john-varga-md John Varga, M.D.
# /dept/dcmb/arushi-varshney-phd Arushi  Varshney, Ph.D.
# /dept/dcmb/angela-violi-phd Angela  Violi, Ph.D.
# /dept/dcmb/vinod-vydiswaran-phd Vinod  Vydiswaran , Ph.D.
# /dept/dcmb/joerg-waldhaus-phd Joerg  Waldhaus, Ph.D.
# /dept/dcmb/nils-walter-phd Nils Walter, Ph.D.
# /dept/dcmb/naisyin-wang-phd Naisyin  Wang, Ph.D.
# /dept/dcmb/shaomeng-wang-phd Shaomeng  Wang, Ph.D.
# /dept/dcmb/yunhao-wang-phd Yunhao  Wang, Ph.D.
# /dept/dcmb/kevin-ward-md Kevin Ward, MD
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# /dept/dcmb/brendon-watson-mdphd Brendon  Watson, M.D.,Ph.D.
# /dept/dcmb/stanley-j-watson-md-phd Stanley J. Watson, M.D., Ph.D.
# /dept/dcmb/joshua-welch-phd Joshua  Welch, Ph.D.
# /dept/dcmb/thomas-werner-phd Thomas Werner, Ph.D.
# /dept/dcmb/max-wicha-md Max Wicha, M.D.
# /dept/dcmb/jenna-wiens-phd Jenna Wiens, Ph.D.
# /dept/dcmb/andrzej-wierzbicki-phd Andrzej  Wierzbicki, Ph.D.
# /dept/dcmb/thomas-wilson-md-phd Thomas  Wilson, M.D., Ph.D.
# /dept/dcmb/patricia-wittkopp-phd Patricia  Wittkopp, Ph.D.
# /dept/dcmb/robert-woods-md Robert Woods, M.D.
# /dept/dcmb/qiong-yang-phd Qiong Yang, Ph.D.
# /dept/dcmb/jianzhi-zhang-phd Jianzhi  Zhang, Ph.D.
# /dept/dcmb/yue-zhao-phd Yue Zhao, Ph.D.
# /dept/dcmb/weichen-zhou-phd Weichen  Zhou, Ph.D.
# /dept/dcmb/xiang-zhou-phd Xiang  Zhou, Ph.D.
# /dept/dcmb/ji-zhu-phd Ji Zhu, Ph.D.
# /dept/dcmb/michal-zochowski-phd Michal  Zochowski, Ph.D.
# /dept/dcmb/sebastian-z%C3%B6llner-phd Sebastian  Zöllner, Ph.D.

# %%
test_faculty = list(faculty_to_info.keys())[6]
print(test_faculty)
# Out:
# Scott Barolo, Ph.D.

# %%
for prof in faculty_to_info:
    if "bio" not in faculty_to_info[prof]:
        page = None
        for i in range(5):
            try:
                ua = choice(user_agents)
                print(ua)
                page = scraper.get(faculty_to_info[prof]["link"],headers={'User-Agent': ua})
                break
            except Exception as e:
                naptime = choice(range(0,5,0.1))
                print("encountered DDOS protection on {}. Sleeping for {} seconds & retrying 😴 ...".format(faculty_list_url.format(0),naptime))
                sleep(naptime)
        else:
            print("failed on {}, stopping".format(prof))
            break
        soup = BeautifulSoup(page.text)
        for art in soup.find_all("article"):
            faculty_to_info[prof]["bio"] = art.text.strip()
            break
# Out:
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Macintosh; Intel Mac OS X 10.10; rv:38.0) Gecko/20100101 Firefox/38.0,
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (X11; Linux x86_64; rv:95.0) Gecko/20100101 Firefox/95.0
# Mozilla/5.0 (Windows NT 10.0; rv:78.0) Gecko/20100101 Firefox/78.0
# Mozilla/5.0 (Windows NT 10.0; rv:91.0) Gecko/20100101 Firefox/91.0

# %%
print(len(faculty_to_info))
if len(faculty_to_info) == 162:
    with open('faculty_to_info.pkl', 'wb') as file:
        # A new file will be created
        dump(faculty_to_info, file)
# Out:
# 162

# %%
faculty_to_info["Michael Boehnke, Ph.D."]
# ua = choice(user_agents)
# print(ua)
# page = scraper.get(faculty_to_info["Michael Boehnke, Ph.D."]["link"],headers={'User-Agent': ua})
# Out:
# {'link': 'https://medicine.umich.edu/dept/dcmb/michael-boehnke-phd',
#  'bio': 'Areas of Interest    \n\nDesign and Analysis of Human Gene Mapping Studies\nIdentifying Genes for Type 2 Diabetes: FUSION\nIdentifying T2D Variants by DNA Sequencing in Multiethnic Samples\nWhole Genome and Exome Sequencing for Bipolar Disorder\nThe Impact of Human Gene Knockouts in Type 2 Diabetes and Related Traits\nWhole Genome Sequencing for Schizophrenia and Bipolar Disorder in the GPC\nAccelerating Medicines Partnership: Enhancement of the Type 2 Diabetes Knowledge Portal\n \n\nWeb Sites    \n\nCenter for Statistical Genetics'}

# %%
query = "chine le"

for prof in faculty_to_info:
    if re.search(query, faculty_to_info[prof]["bio"]):
        print(prof)
# Out:
# Veera Baladandayuthapani, Ph.D.
# Johann Gagnon-Bartsch, Ph.D.
# Yuanfang Guan, Ph.D.
# Hui  Jiang, Ph.D.
# Danai  Koutra, Ph.D.
# Joonsang Lee, Ph.D.
# Jie Liu, Ph.D.
# Kayvan Najarian, Ph.D.
# Nambi  Nallasamy, M.D.
# Matthew  O'Meara, Ph.D.
# Clayton  Scott, Ph.D.
# Karandeep  Singh, M.D., MMSc
# Chandra  Sripada, M.D., Ph.D.
# Vinod  Vydiswaran , Ph.D.
# Joshua  Welch, Ph.D.
# Jenna Wiens, Ph.D.
